# %%
import pyautogui as pag
import os
import time
import pandas as pd
import VSchool_lib as vsl
import vs_auto as vsa
import requests
import clipboard as cb
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import random
import numpy as np

user_data_path = '/home/lloli/Documents/GitHub/Sorn/usr/user_data.csv'

# %%
token = '4HciAjHnI7lPRTz809eH4COiSVai7A4iPEG86P54lj7'
url = 'https://notify-api.line.me/api/notify'
headers = {
            'content-type':
            'application/x-www-form-urlencoded',
            'Authorization':'Bearer '+token
           }

# %%
def notify(msg):
    r = requests.post(url, headers=headers , data = {'message':msg})

# %%
def join_path(file_path):
    return os.path.join(SORN,file_path)

# %%
SORN = '/home/lloli/Documents/GitHub/Sorn'
ter = join_path('assets/$.png')
YELLOW = join_path('assets/yellow.png')
YELLOW_DARK = join_path('assets/yellow_dark.png')
PRETEST = join_path('assets/PRETEST.png')
LECTURE1 = join_path('assets/LECTURE1.png')
LECTURE2 = join_path('assets/LECTURE2.png')
LECTURE3 = join_path('assets/LECTURE3.png')
LECTURE4 = join_path('assets/lecture4.png')
SAVE_LECTURE = join_path('assets/SAVE_LECTURE.png')
SAVE_LECTURE2 = join_path('assets/SAVE_LECTURE2.png')
POSTTEST = join_path('assets/POSTTEST.png')
LAST = join_path('assets/LAST.png')
LAST2 = join_path('assets/REVIEW.png')
FINALTEST = join_path('assets/FINAL.png')
REVIEW = join_path('assets/again.png')
STAR = join_path('assets/STAR.png')
PT_5 = join_path('assets/pt_5.png')
PT_6 = join_path('assets/pt_6.png')
PT_7 = join_path('assets/pt_7.png')
PT_8 = join_path('assets/pt_8.png')
PT_9 = join_path('assets/pt_9.png')
PT_10 = join_path('assets/pt_10.png')
PT_50 = join_path('assets/pt_50.png')
ENG = join_path('assets/fore.png')
OK = join_path('assets/ok.png')
NOTDONE = join_path('assets/notdone.png')
CHANGESUBJ = join_path('assets/CHANGESUBJ.png')
SUBJ_PHYSICS60 = join_path('assets/subjects/PHYSICS60.png')
SUBJ_MATH60 = join_path('assets/subjects/MATH60.png')
SUBJ_BIOLOGY60 = join_path('assets/subjects/BIOLOGY60.png')
SUBJ_CHEM60 = join_path('assets/subjects/CHEM60.png')
SUBJ_SOCIAL = join_path('assets/subjects/SOCIALSCIENCE.png')
SUBJ_TH = join_path('assets/subjects/THAI.png')
SUBJ_ENG = join_path('assets/subjects/ENG.png')
SUBJ_HE = join_path('assets/subjects/HE.png')
SUBJ_PE = join_path('assets/subjects/PE.png')
SUBJ_ART = join_path('assets/subjects/ART.png')
SUBJ_MATHEX = join_path('assets/subjects/MATHEX.png')
SUBJ_ASTRONOMY = join_path('assets/subjects/ASTRONOMY.png')
SUBJ_BIO = join_path('assets/subjects/bio.png')
SUBJ_MATH = join_path('assets/subjects/math.png')
SUBJ_CHEM = join_path('assets/subjects/chem.png')
USERNAME = join_path('assets/kpt.png')
PASSWORD = join_path('assets/pass.png')
LOGIN = join_path('assets/login.png')
LOGIN_AGREE = join_path('assets/login_agree.png')
KOY = join_path('assets/koy.png')
MS6 = join_path('assets/ms6.png')
SEMESTER1 = join_path('assets/semester1.png')
SEMESTER2 = join_path('assets/semester2.png')
LOGOUT = join_path('assets/logout.png')
HOME = join_path('assets/HOME.png')

# %%
def write_usr_pas(usr,pas):
    lc = pag.locateCenterOnScreen(USERNAME)
    if lc == None:
        pag.tripleClick(pag.Point(428,498))
        pag.hotkey('ctrl','c')
        err = 0
        while not 'kpt' in cb.paste():
            pag.tripleClick(pag.Point(428,498))
            pag.click(pag.Point(428,498))
            
            pag.hotkey('ctrl','c')
            err= err+1
            if err == 10:break
        pag.write(usr)
    else:
        pag.click(lc)
        pag.write(usr)


    lc = pag.locateCenterOnScreen(PASSWORD)
    if lc == None:
        pag.click(pag.Point(428,538))
        time.sleep(0.2)
        pag.click(pag.Point(428,538))
        pag.hotkey('ctrl','a')
        pag.write(pas)
    else:
        pag.click(lc)
        pag.click(pag.Point(428,538))
        pag.write(pas)

    msg = '\nUSERNAME = {} \nPASSWORD = {}'.format(usr,pas)
    notify(msg)
    print(msg)

# %%
def login():
    lc = pag.locateCenterOnScreen(LOGIN)
    if lc == None:
        pag.click(pag.Point(428,625))
    else:
        pag.click(lc)
    time.sleep(1)
    lc = pag.locateCenterOnScreen(LOGIN_AGREE)
    err = 0
    while lc == None:
        err = err + 1
        lc = pag.locateCenterOnScreen(LOGIN_AGREE)
        time.sleep(0.4)
        if err == 5:
            break

    pag.click(lc)
    print('LOGGED IN')
    time.sleep(2)

# %%
def click_koy():
    lc = pag.locateCenterOnScreen(KOY)
    if lc == None:
        pag.click(pag.Point(x=1101, y=896))
    else:
        pag.click(lc)  
    msg = 'Clicked Koy'
    notify(msg)
    print(msg)

# %%
def click_ms6():
    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(MS6)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(MS6)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=1308, y=828))
    else:
        pag.click(lc)  
    msg = 'Clicked MS6'
    notify(msg)
    print(msg)

# %%
def click_semester2():
    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(SEMESTER2)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(SEMESTER2)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=800, y=896))
    else:
        pag.click(lc)  

    msg = 'Clicked Semester 2'
    notify(msg)
    print(msg)

# %%
def click_semester1():
    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(SEMESTER1)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(SEMESTER1)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=1101, y=896))
    else:
        pag.click(lc)  

    msg = 'Clicked Semester 1'
    notify(msg)
    print(msg)

# %%
def logout(name = None,usr = None):

    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(LOGOUT)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(LOGOUT)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=1418, y=331))
    else:
        pag.click(lc)  

    msg = 'Logged Out {}'.format(usr)
    notify(msg)
    print(msg)

# %%
def shutdown():
    pag.keyDown('ctrl')
    pag.keyDown('alt')
    time.sleep(0.5)
    pag.press('t')
    pag.keyUp('ctrl')
    pag.keyUp('alt')
    time.sleep(2)
    pag.write('sudo shutdown -h now')
    time.sleep(0.5)
    msg = 'Shutting down'
    print(msg)
    notify(msg)
    pag.press('enter')
    time.sleep(2)
    pag.write('1234567890')
    pag.press('enter')

# %%
g_login = GoogleAuth()
g_login.LocalWebserverAuth()
drive = GoogleDrive(g_login)

folderName = 'vschool_fukk'

folders = drive.ListFile(
    {'q': "title='" + folderName + "' and mimeType='application/vnd.google-apps.folder' and trashed=false"}).GetList()
for folder in folders:
    if folder['title'] == folderName:
        folderID = folder['id']
file1 = drive.CreateFile({'title':'VSCHOOL_FULL_ANS.csv','parents': [{'id': folderID}]})
file2 = drive.CreateFile({'title':'USR.csv','parents': [{'id': folderID}]})
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=860236391617-bcbmishunp3rasacu3je1982ic0v04qh.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
def notify_IFTTT(a):
    report = {}
    report['value1'] = a
    requests.post("https://maker.ifttt.com/trigger/Final_Ace/with/key/cLvSycLN_IBxyYbpoy49QQ", data=report)

# %%
def click_STAR():
    lc = pag.locateCenterOnScreen(STAR)
    pag.click(lc)

# %%
def find_YELLOW():
    lc = pag.locateCenterOnScreen(YELLOW)
    if lc == None:
        lc = pag.locateCenterOnScreen(YELLOW_DARK)
    return lc

# %%
def find_LAST():
    lc = pag.locateCenterOnScreen(LAST)
    if lc == None:
        lc = pag.locateCenterOnScreen(LAST2)
    while lc == None:
        pag.press('pagedown')
        time.sleep(1)
        lc = pag.locateCenterOnScreen(LAST)
        if lc == None:
            lc = pag.locateCenterOnScreen(LAST2)
        
    return lc

# %%
def click_YELLOW(AT_FINAL):
    if AT_FINAL == False:
        lc = find_YELLOW()
        while lc == None: 

            lc = find_YELLOW()

            if lc == None:
                pag.press('pagedown')
                time.sleep(1)
                lc = find_YELLOW()

            lc = find_YELLOW()

            if lc == None:
                click_STAR()
                time.sleep(1)
                lc = find_YELLOW()
                if lc == None:
                    click_STAR()
                    time.sleep(1)
                    lc = find_YELLOW()
                    if lc == None: 
                        click_STAR()    
                        time.sleep(1)
                        lc = find_YELLOW()
                        if lc == None: 
                            click_STAR()    
                            time.sleep(1)
                            lc = find_YELLOW()
                            if lc == None: 
                                click_STAR()    
                                time.sleep(1)
                                lc = find_YELLOW()
                                if lc == None: 
                                    click_STAR()    
                                    time.sleep(1)
                                    lc = find_YELLOW()
            if lc == None:
                for i in range(5):
                    pag.press('pageup')

            lc = find_YELLOW()

    if AT_FINAL == True:
        lc = find_LAST()

    pag.click(lc)
    time.sleep(0.2)
    pag.click(lc)
    pag.click(lc)

# %%
def is_PRETEST():
    lc = pag.locateCenterOnScreen(PRETEST)
    if lc == None: return False
    else: return True

# %%
def is_POSTTEST():
    lc = pag.locateCenterOnScreen(POSTTEST)
    if lc == None: return False
    else: return True

# %%
def is_LECTURE():
    lc = pag.locateCenterOnScreen(LECTURE1)
    z = 0
    if lc == None:
        lc = pag.locateCenterOnScreen(LECTURE2)
        z = 1
        if lc == None:
            lc = pag.locateCenterOnScreen(LECTURE3)
            z = 0
            if lc == None:
                lc = pag.locateCenterOnScreen(LECTURE4)
                z = 0
    if lc == None: return False
    else: return True

# %%
def skip_LECTURE():
    lc = pag.locateCenterOnScreen(LECTURE1)
    z = 0
    if lc == None:
        lc = pag.locateCenterOnScreen(LECTURE2)
        z = 1
        if lc == None:
            lc = pag.locateCenterOnScreen(LECTURE3)
            z = 0
            if lc == None:
                lc = pag.locateCenterOnScreen(LECTURE4)
                z = 0
                if lc == None:
                    z = 1
                    lc = pag.locateCenterOnScreen(LECTURE5)
        
    
    err = 1
    
    while lc == None:
        lc = pag.locateCenterOnScreen(LECTURE1)
        z = 0
        if lc == None:
            lc = pag.locateCenterOnScreen(LECTURE2)
            z = 1
            if lc == None:
                lc = pag.locateCenterOnScreen(LECTURE3)
                z = 0
                if lc == None:
                    lc = pag.locateCenterOnScreen(LECTURE4)
                    z = 0
                    err = err +1
                    if err == 5: break

    if lc == None:
        lc = pag.Point(x=1441, y=382)

    if z == 0:
        pag.click(lc)
        lc = pag.locateCenterOnScreen(SAVE_LECTURE)
        if lc == None:
             lc = pag.locateCenterOnScreen(SAVE_LECTURE2)
        while lc == None:
            lc = pag.locateCenterOnScreen(SAVE_LECTURE)
            if lc == None:
                lc = pag.locateCenterOnScreen(SAVE_LECTURE2)
                print('SAVE_LECTURE not found')
        pag.click(lc)
        time.sleep(0.3)
        pag.click(lc)
    
    elif z == 1:
        pag.click(lc)
        time.sleep(0.3)
        pag.click(lc)

# %%
def is_FINALTEST():
    lc = pag.locateCenterOnScreen(FINALTEST)
    if lc == None: return False
    else: return True

# %%
def is_REVIEW():
    lc = pag.locateCenterOnScreen(REVIEW)
    if lc == None: return False
    else: return True

# %%
def get_PT():
    i = 0
    lc = None
    while lc == None:
        lc = pag.locateCenterOnScreen(PT_5)
        if not lc == None: 
            print(5,'pts')
            return 5
        lc = pag.locateCenterOnScreen(PT_6)
        if not lc == None: 
            print(6,'pts')
            return 6
        lc = pag.locateCenterOnScreen(PT_7)
        if not lc == None: 
            print(7,'pts')
            return 7
        lc = pag.locateCenterOnScreen(PT_8)
        if not lc == None: 
            print(8,'pts')
            return 8
        lc = pag.locateCenterOnScreen(PT_9)
        if not lc == None: 
            print(9,'pts')
            return 9
        lc = pag.locateCenterOnScreen(PT_10)
        if not lc == None: 
            print(10,'pts')
            return 10
        lc = pag.locateCenterOnScreen(PT_50)
        if not lc == None: 
            print(50,'pts')
            return 50
        i = i +1
        if i == 3:
            return 0

# %%
def get_TYPE():
    p = 0
    while p == 0:
        if is_PRETEST():
            print('is PRETEST')
            p=1
        elif is_LECTURE():
            print('is LECTURE')
            p=2
        elif is_POSTTEST():
            print('is POSTTEST')
            p=3
        elif is_FINALTEST():
            print('is FINALTEST')
            p=4
        elif is_REVIEW():
            print('is REVIEW')
            p=4
    print(p)
    return p

# %%
def take_subject(at_final = False,lang= 'th',nwrong = 1,subj=None,name = None):
    if subj == None:
        subj = ''
    AT_FINAL = at_final
    
    FINALTEST_ACED = False
    time.sleep(1)

    ok = pag.locateCenterOnScreen(OK)
    notdone = pag.locateCenterOnScreen(NOTDONE)
    if (not ok == None) or (not notdone == None):
        pag.press('enter')
        lc = pag.locateCenterOnScreen(NOTDONE)
        while lc == None:
            lc = pag.locateCenterOnScreen(NOTDONE)

        pag.click(lc)
        return False

    while FINALTEST_ACED == False:
        file1.Upload()
        pt = 0
        time.sleep(1)


        click_YELLOW(AT_FINAL)
        p = get_TYPE()

        if p == 1:
            vsl.send()
            time.sleep(1)
            vsl.confirm()
            vsl.x()
            pt = 0
        if p == 2:
            skip_LECTURE()
            pt = 0
        if p == 3:
            while pt < 5:
                print(subj,' Taking POSTTEST')
                msg = subj + ' Taking POSTTEST'
                notify(msg)
                n,nn = vsa.auto_take10(lang,nwrong)
                time.sleep(2)
                vsl.send()
                vsl.confirm()
                pt = get_PT()
                msg = subj+'\nn(Correct) = ' +str(n) +'\nn(Done) = ' + str(nn)
                notify(msg)
                if not n == 10:
                    
                    pag.moveTo(x=1463, y=489)
                    vsl.agree_PT()
                    vsl.gather()
                    file1.SetContentFile('/home/lloli/Documents/GitHub/Sorn/all.csv')
                    file1.Upload()
                    break
                else:
                    vsl.decline()
                    msg = subj + ' POSTTEST Passed'
                    notify(msg)
                    break
            msg = subj+ ' POSTTEST Done'
            notify(msg)
            pt = 0
                    

        if p == 4:
            AT_FINAL = True
            msg = subj + ' AT_FINAL'
            notify(msg)
            notify_IFTTT(msg)
            n = 0
            while not n == 50:
                msg = subj +' Taking FINALTEST'
                notify(msg)
                n,nn,inp = vsa.auto_take50(lang)
                time.sleep(2)
                vsl.send()
                vsl.confirm()
                msg = subj +'\nn(Correct) = ' +str(n) +'\nn(Done) = ' + str(nn)
                notify(msg)

                if n == 50:
                    pag.moveTo(x=1463, y=489)
                    time.sleep(2)
                    vsl.decline()
                    FINALTEST_ACED = True
                    msg = 'FINALTEST Aced'
                    notify(msg)
                    notify_IFTTT(msg)
                    break

                
                pag.moveTo(x=1463, y=489)
                time.sleep(2)
                vsl.agree_PT()
                vsl.gather()
                file1.SetContentFile('/home/lloli/Documents/GitHub/Sorn/all.csv')
                file1.Upload()
                click_YELLOW(True)
                


            msg = 'FINALTEST Done'
            notify(msg)

# %%
# for sec in range(3):
#     time.sleep(1)

# if  pag.locateCenterOnScreen(ENG) == None:
#     lang = 'th'
# else: lang = 'en'
# msg = 'LANG = ' + lang
# print(msg)
# notify(msg)
# take_subject(False,lang = 'en')

# %%
def click_CHANGESUBJ():
    lc = pag.locateCenterOnScreen(CHANGESUBJ)
    while lc == None:
        lc = pag.locateCenterOnScreen(CHANGESUBJ)
        if lc == None: print('CHANGESUBJ not found')
    pag.click(lc)
    pag.moveTo(1788,589)

# %%
def click_SUBJ(subj):
    pag.moveTo(100,100)
    switcher = {
        'phy60':SUBJ_PHYSICS60,
        'math60':SUBJ_MATH60,
        'bio60':SUBJ_BIOLOGY60,
        'chem60':SUBJ_CHEM60,
        'social':SUBJ_SOCIAL,
        'th':SUBJ_TH,
        'eng':SUBJ_ENG,
        'he':SUBJ_HE,
        'pe':SUBJ_PE,
        'art':SUBJ_ART,
        'mathex':SUBJ_MATHEX,
        'astro':SUBJ_ASTRONOMY,
        'math' :SUBJ_MATH,
        'bio' :SUBJ_BIO,
        'chem' :SUBJ_CHEM
    }

    lc = pag.locateCenterOnScreen(switcher[subj])
    while lc == None:
        pag.press('pagedown')
        time.sleep(1)
        lc = pag.locateCenterOnScreen(switcher[subj])
        if lc == None:
            pag.press('pagedown')
            time.sleep(1)
            lc = pag.locateCenterOnScreen(switcher[subj])
        if lc == None:
            pag.press('pageup')
            time.sleep(1)
            lc = pag.locateCenterOnScreen(switcher[subj])
        if lc == None:
            pag.press('pageup')
            time.sleep(1)
            lc = pag.locateCenterOnScreen(switcher[subj])
    pag.click(lc)

# %%
def click_HOME():
    lc = pag.locateCenterOnScreen(HOME)
    err = 0 
    while lc == None:
        lc = pag.locateCenterOnScreen(HOME)
        err = err+1
        if err == 7:
            break
    if lc == None:
        pag.click(pag.Point(x=449, y=340))
    else: pag.click(lc)

# %%
def listToString(s):  
    
    str1 = ""  
     
    for ele in s:  
        str1 += ele 
        str1 += ' ' 
     
    return str1

# %%
def take_semester_df(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2',data = None):


    
    if lst_subj_NAF == 'all':
        lst_subj_NAF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_AF == 'all':
        lst_subj_AF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']

    if lst_subj_AF == 'allterm21':
        lst_subj_AF = ['math','phy60','chem60','social','th','eng','he','pe','mathex','astro']


    if lst_subj_NAF == 'allterm2':
        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']

    if lst_subj_NAF == 'allterm21':
        lst_subj_NAF = ['math','phy60','chem60','social','th','eng','he','pe','mathex','astro']


    ind = df[(df['name']== name) & (df['semester']== semester)].index[0]
    al_sbj_done = list(data[data['name']== name ]['subject_done'].values)[0]

    if type(al_sbj_done) == type(1.0):
        al_sbj_done = []
        except_NAF = []
    else:
        except_NAF = al_sbj_done.replace("'",'').replace("[",'').replace("]",'').replace(" ",'').split(',')
    
    if not except_NAF == []:
        for rm_subj in except_NAF:
            lst_subj_NAF.remove(rm_subj)

        msg = listToString(except_NAF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)
    else: 
        except_NAF = []

    notify('except_NAF = ' + str(except_NAF))


    
    if not except_AF == None:
        for rm_subj in except_AF:
            lst_subj_AF.remove(rm_subj)

        msg = listToString(except_AF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)

    if not lst_subj_NAF == None:
        random.shuffle(lst_subj_NAF)
        subj_todo = len(lst_subj_NAF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_NAF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                d = take_subject(False,lang,1,subj,name)
                if d == False:
                    msg = '\nTaking {} in Semester 1'.format(subj)
                    click_semester1()
                    click_SUBJ(subj)
                    take_subject(False,lang,1,subj)
                    click_HOME()
                    time.sleep(0.8)
                    pag.click(1210,875)
                    time.sleep(0.8)
                    pag.click(1210,875)
                    time.sleep(0.8)
                    pag.click(1210,875)
                    click_SUBJ(subj)
                    take_subject(False,lang,1,subj)


                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                except_NAF.append(subj)
                df.at[ind,'subject_done'] = except_NAF
                df.to_csv(user_data_path)
                file2.SetContentFile(user_data_path)
                file2.Upload()
                subj_done = subj_done + 1
                time.sleep(2)


                click_CHANGESUBJ()


    if not lst_subj_AF == None:
        random.shuffle(lst_subj_AF)
        subj_todo = len(lst_subj_AF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_AF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                take_subject(True,lang,5,subj,name)

                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                subj_done = subj_done + 1

                time.sleep(2)

                click_CHANGESUBJ()

# %%
def take_semester(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2'):


    
    if lst_subj_NAF == 'all':
        lst_subj_NAF = ['math60','phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_AF == 'all':
        lst_subj_AF = ['math60','phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']

    if lst_subj_AF == 'allterm21':
        lst_subj_AF = ['math','phy60','chem60','social','th','eng','he','pe','mathex','astro']


    if lst_subj_NAF == 'allterm2':
        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']

    if lst_subj_NAF == 'allterm21':
        lst_subj_NAF = ['math','phy60','chem60','social','th','eng','he','pe','mathex','astro']

    if not except_NAF == []:
        for rm_subj in except_NAF:
            lst_subj_NAF.remove(rm_subj)

        msg = listToString(except_NAF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)
    else: 
        except_NAF = []

    notify('except_NAF = ' + str(except_NAF))


    
    if not except_AF == None:
        for rm_subj in except_AF:
            lst_subj_AF.remove(rm_subj)

        msg = listToString(except_AF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)

    if not lst_subj_NAF == None:
        random.shuffle(lst_subj_NAF)
        subj_todo = len(lst_subj_NAF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_NAF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                d = take_subject(False,lang,1,subj,name)
                if d == False:
                    msg = '\nTaking {} in Semester 1'.format(subj)
                    click_semester1()
                    click_SUBJ(subj)
                    take_subject(False,lang,1,subj)
                    click_HOME()
                    time.sleep(0.8)
                    pag.click(1210,875)
                    time.sleep(0.8)
                    pag.click(1210,875)
                    time.sleep(0.8)
                    pag.click(1210,875)
                    click_SUBJ(subj)
                    take_subject(False,lang,1,subj)


                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                except_NAF.append(subj)
                subj_done = subj_done + 1
                time.sleep(2)


                click_CHANGESUBJ()


    if not lst_subj_AF == None:
        random.shuffle(lst_subj_AF)
        subj_todo = len(lst_subj_AF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_AF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                take_subject(True,lang,5,subj,name)

                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                subj_done = subj_done + 1

                time.sleep(2)

                click_CHANGESUBJ()

# %%
def auto_usrsem2(name,usr,pas,semester,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None,data = None):
    msg = '\nName : {}'.format(name)
    notify(msg)
    print(msg)
    write_usr_pas(usr,pas)
    login()
    click_koy()
    click_ms6()
    click_semester2()
    take_semester_df(lst_subj_NAF,lst_subj_AF,except_NAF,except_AF,name,semester,data = data)
    time.sleep(1)
    logout(name,usr)
    time.sleep(5)

# %%
def auto_usrsem1(name,usr,pas,semester,df,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None,data = None):
    msg = '\nName : {}'.format(name)
    notify(msg)
    print(msg)
    write_usr_pas(usr,pas)
    login()
    click_koy()
    click_ms6()
    click_semester1()
    take_semester_df(lst_subj_NAF,lst_subj_AF,except_NAF,except_AF,name,semester,data)
    time.sleep(1)
    logout(name,usr)
    time.sleep(5)

# %%
def auto_df_todo(df__todo):

    print(df__todo)

    for i in range(df__todo.shape[0]):
        name = df__todo.loc[i]['name']
        usr = df__todo.loc[i]['username']
        pas  = df__todo.loc[i]['password']
        sem = df__todo.loc[i]['semester']
        auto_usrsem2(name,usr,pas,'6/2','allterm21',data = df__todo)
        df__todo.to_csv('usr/user_done_data.csv')

        ind = df[df['name']== name].index[0]
        df.at[ind,'status'] = 'awaiting2'
        df.to_csv(user_data_path,index=False)
        df__todo.to_csv('usr/user_done_data.csv')
        file2.SetContentFile(user_data_path)
        file2.Upload()

# %%
def auto_df_todo2(df__todo):

    for i in range(df__todo.shape[0]):
        name = df__todo.loc[i]['name']
        usr = df__todo.loc[i]['username']
        pas  = df__todo.loc[i]['password']
        sem = df__todo.loc[i]['semester']
        auto_usrsem1(name,usr,pas,'6/1','all',data = df__todo)
        df__todo.loc[i] = df__todo.loc[i].replace('standby','awaiting')
        df__todo.to_csv('usr/user_done_data.csv')

        ind = df[df['name']== name].index[0]
        df.at[ind,'status'] = 'awaiting'
        df.to_csv(user_data_path,index=False)
        file2.SetContentFile(user_data_path)
        file2.Upload()

# %%
'''
SUBJ_PHYSICS60 = join_path('assets/subjects/PHYSICS60.png')
SUBJ_MATH60 = join_path('assets/subjects/MATH60.png')
SUBJ_BIOLOGY60 = join_path('assets/subjects/BIOLOGY60.png')
SUBJ_CHEM60 = join_path('assets/subjects/CHEM60.png')
SUBJ_SOCIAL = join_path('assets/subjects/SOCIALSCIENCE.png')
SUBJ_TH = join_path('assets/subjects/THAI.png')
SUBJ_ENG = join_path('assets/subjects/ENG.png')
SUBJ_HE = join_path('assets/subjects/HE.png')
SUBJ_PE = join_path('assets/subjects/PE.png')
SUBJ_MATHEX = join_path('assets/subjects/MATHEX.png')
SUBJ_ASTRONOMY = join_path('assets/subjects/ASTRONOMY.png')
------------------------------------------------------------
        'phy60':SUBJ_PHYSICS60,
        'math60':SUBJ_MATH60,
        'bio60':SUBJ_BIghgh f  'astro':SUBJ_ASTRONOMY
j
    if lst_subhubj_AF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_NAF == 'allterm2':
        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']

    if lst_subj_NAF == 'allterm21':
        lst_subj_NAF = ['math','phy60','chem60','social','th','eng','he','pe','mathex','astro']

--------------------------------------------------------------------------------
take_semester(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2')

auto_sem2(name,usr,pas,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None)
'''
# Out:
# "\nSUBJ_PHYSICS60 = join_path('assets/subjects/PHYSICS60.png')\nSUBJ_MATH60 = join_path('assets/subjects/MATH60.png')\nSUBJ_BIOLOGY60 = join_path('assets/subjects/BIOLOGY60.png')\nSUBJ_CHEM60 = join_path('assets/subjects/CHEM60.png')\nSUBJ_SOCIAL = join_path('assets/subjects/SOCIALSCIENCE.png')\nSUBJ_TH = join_path('assets/subjects/THAI.png')\nSUBJ_ENG = join_path('assets/subjects/ENG.png')\nSUBJ_HE = join_path('assets/subjects/HE.png')\nSUBJ_PE = join_path('assets/subjects/PE.png')\nSUBJ_MATHEX = join_path('assets/subjects/MATHEX.png')\nSUBJ_ASTRONOMY = join_path('assets/subjects/ASTRONOMY.png')\n------------------------------------------------------------\n        'phy60':SUBJ_PHYSICS60,\n        'math60':SUBJ_MATH60,\n        'bio60':SUBJ_BIghgh f  'astro':SUBJ_ASTRONOMY\nj\n    if lst_subhubj_AF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']\n\n\n    if lst_subj_NAF == 'allterm2':\n        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']\n\n    if lst_subj_NAF == 'allterm21':\n        lst_subj_NAF = ['math','phy60','chem60','social','th','eng','he','pe','mathex','astro']\n\n--------------------------------------------------------------------------------\ntake_semester(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2')\n\nauto_sem2(name,usr,pas,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None)\n"

# %%
df = pd.read_csv('/home/lloli/Documents/GitHub/Sorn/usr/user_data.csv').rename(columns={'Name':'name'})

df_todo = df[(df.semester=='6/2') & (df.status == 'standby')].sort_values('subject_done',ascending=False).sort_values('paid',ascending=False).reset_index(drop=True)

# %%
df_todo
# Out:
#    Unnamed: 0     name  username password class  \
# 0          59  Andrew2  kpt13661  sk13661   6/2
#
#                                         subject_done semester  paid  price  \
# 0  ['he', 'astro', 'eng', 'math', 'th', 'chem60',...      6/2   270    270
#
#     status
# 0  standby

# %%
data = pd.read_csv('/home/lloli/Documents/GitHub/Sorn/all.csv')
data = data.drop(data[data['id'] == data['ans']].index) 
data2 = pd.DataFrame()
data2['id'] = data['id']
data2['ans'] = data['ans']
data2.to_csv('/home/lloli/Documents/GitHub/Sorn/all.csv',index=False)

auto_df_todo(df_todo)

shutdown()
# Out:
# ( 1 ) Choice clicked
#
#
# Loading6
# ID foundรหัสข้อสอบ : J-24-18-6
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading7
# ID foundรหัสข้อสอบ : J-24-18-4
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading8
# ID foundรหัสข้อสอบ : J-24-18-14
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading9
# ID foundรหัสข้อสอบ : J-24-18-19
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading10
# ID foundรหัสข้อสอบ : J-24-18-21
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading11
# ID foundรหัสข้อสอบ : J-24-18-9
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading12
# ID foundรหัสข้อสอบ : J-24-18-28
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading13
# ID foundรหัสข้อสอบ : J-24-18-5
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading14
# ID foundรหัสข้อสอบ : J-24-18-25
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading15
# ID foundรหัสข้อสอบ : J-24-18-16
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading16
# ID foundรหัสข้อสอบ : J-24-18-23
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading17
# ID foundรหัสข้อสอบ : J-24-18-18
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading18
# ID foundรหัสข้อสอบ : J-24-18-10
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading19
# ID foundรหัสข้อสอบ : J-24-19-185
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading20
# ID foundรหัสข้อสอบ : J-24-19-158
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading21
# ID foundรหัสข้อสอบ : J-24-19-149
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading22
# ID foundรหัสข้อสอบ : J-24-19-176
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading23
# ID foundรหัสข้อสอบ : J-24-19-179
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading24
# ID foundรหัสข้อสอบ : J-24-19-150
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading25
# ID foundรหัสข้อสอบ : J-24-19-171
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading26
# ID foundรหัสข้อสอบ : J-24-19-157
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading27
# ID foundรหัสข้อสอบ : J-24-19-164
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading28
# ID foundรหัสข้อสอบ : J-24-19-162
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading29
# ID foundรหัสข้อสอบ : J-24-19-180
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading30
# ID foundรหัสข้อสอบ : J-24-19-151
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading31
# ID foundรหัสข้อสอบ : J-24-19-146
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading32
# ID foundรหัสข้อสอบ : J-24-19-156
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading33
# ID foundรหัสข้อสอบ : J-24-19-165
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading34
# ID foundรหัสข้อสอบ : J-24-19-148
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading35
# ID foundรหัสข้อสอบ : J-24-19-161
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading36
# ID foundรหัสข้อสอบ : J-24-20-199
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading37
# ID foundรหัสข้อสอบ : J-24-20-204
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading38
# ID foundรหัสข้อสอบ : J-24-20-191
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading39
# ID foundรหัสข้อสอบ : J-24-20-194
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading40
# ID foundรหัสข้อสอบ : J-24-20-190
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading41
# ID foundรหัสข้อสอบ : J-24-20-188
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading42
# ID foundรหัสข้อสอบ : J-24-20-208
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading43
# ID foundรหัสข้อสอบ : J-24-20-215
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading44
# ID foundรหัสข้อสอบ : J-24-20-203
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading45
# ID foundรหัสข้อสอบ : J-24-20-214
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading46
# ID foundรหัสข้อสอบ : J-24-20-186
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading47
# ID foundรหัสข้อสอบ : J-24-20-189
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading48
# ID foundรหัสข้อสอบ : J-24-20-210
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading49
# ID foundรหัสข้อสอบ : J-24-20-209
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading50
# ID foundรหัสข้อสอบ : J-24-20-207
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading51
# ID foundรหัสข้อสอบ : J-24-20-205
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading52
# ID foundรหัสข้อสอบ : J-24-20-200
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Done, n(Correct) =  50
# n(Done) =  50
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# phy60 DONE
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# SAVE_LECTURE not found
# is POSTTEST
# 3
# social  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-04-53-91
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-04-53-93
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-04-53-84
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-04-53-101
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-04-53-85
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-04-53-87
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-04-53-92
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-04-53-98
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-04-53-96
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-04-53-97
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is LECTURE
# 2
# is POSTTEST
# 3
# social  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-04-54-113
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-04-54-115
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-04-54-110
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-04-54-117
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-04-54-178
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-04-54-114
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-04-54-120
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-04-54-112
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-04-54-104
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-04-54-103
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# social  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-04-55-141
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-04-55-122
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-04-55-126
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-04-55-128
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-04-55-123
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-04-55-129
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-04-55-136
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-04-55-137
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-04-55-127
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-04-55-134
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is LECTURE
# 2
# is POSTTEST
# 3
# social  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-04-56-145
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-04-56-144
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-04-56-152
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-04-56-153
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-04-56-149
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-04-56-159
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-04-56-146
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-04-56-142
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-04-56-158
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-04-56-157
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is FINALTEST
# 4
# ID foundรหัสข้อสอบ : 6-04-53-96
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading4
# ID foundรหัสข้อสอบ : 6-04-53-97
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading5
# ID foundรหัสข้อสอบ : 6-04-53-89
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading6
# ID foundรหัสข้อสอบ : 6-04-53-83
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading7
# ID foundรหัสข้อสอบ : 6-04-53-93
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading8
# ID foundรหัสข้อสอบ : 6-04-53-87
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading9
# ID foundรหัสข้อสอบ : 6-04-53-82
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading10
# ID foundรหัสข้อสอบ : 6-04-53-99
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading11
# ID foundรหัสข้อสอบ : 6-04-53-84
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading12
# ID foundรหัสข้อสอบ : 6-04-53-101
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading13
# ID foundรหัสข้อสอบ : 6-04-53-171
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading14
# ID foundรหัสข้อสอบ : 6-04-53-92
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading15
# ID foundรหัสข้อสอบ : 6-04-53-94
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading16
# ID foundรหัสข้อสอบ : 6-04-54-115
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading17
# ID foundรหัสข้อสอบ : 6-04-54-109
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading18
# ID foundรหัสข้อสอบ : 6-04-54-103
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading19
# ID foundรหัสข้อสอบ : 6-04-54-120
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading20
# ID foundรหัสข้อสอบ : 6-04-54-105
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading21
# ID foundรหัสข้อสอบ : 6-04-54-118
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading22
# ID foundรหัสข้อสอบ : 6-04-54-178
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading23
# ID foundรหัสข้อสอบ : 6-04-54-111
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading24
# ID foundรหัสข้อสอบ : 6-04-54-106
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading25
# ID foundรหัสข้อสอบ : 6-04-54-117
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading26
# ID foundรหัสข้อสอบ : 6-04-54-104
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading27
# ID foundรหัสข้อสอบ : 6-04-54-108
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading28
# ID foundรหัสข้อสอบ : 6-04-54-121
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading29
# ID foundรหัสข้อสอบ : 6-04-55-132
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading30
# ID foundรหัสข้อสอบ : 6-04-55-128
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading31
# ID foundรหัสข้อสอบ : 6-04-55-124
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading32
# ID foundรหัสข้อสอบ : 6-04-55-130
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading33
# ID foundรหัสข้อสอบ : 6-04-55-122
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading34
# ID foundรหัสข้อสอบ : 6-04-55-127
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading35
# ID foundรหัสข้อสอบ : 6-04-55-138
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading36
# ID foundรหัสข้อสอบ : 6-04-55-129
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading37
# ID foundรหัสข้อสอบ : 6-04-55-126
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading38
# ID foundรหัสข้อสอบ : 6-04-55-140
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading39
# ID foundรหัสข้อสอบ : 6-04-55-135
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading40
# ID foundรหัสข้อสอบ : 6-04-55-139
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading41
# ID foundรหัสข้อสอบ : 6-04-56-150
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading42
# ID foundรหัสข้อสอบ : 6-04-56-160
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading43
# ID foundรหัสข้อสอบ : 6-04-56-155
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading44
# ID foundรหัสข้อสอบ : 6-04-56-161
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading45
# ID foundรหัสข้อสอบ : 6-04-56-148
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading46
# ID foundรหัสข้อสอบ : 6-04-56-149
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading47
# ID foundรหัสข้อสอบ : 6-04-56-144
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading48
# ID foundรหัสข้อสอบ : 6-04-56-154
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading49
# ID foundรหัสข้อสอบ : 6-04-56-156
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading50
# ID foundรหัสข้อสอบ : 6-04-56-151
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading51
# ID foundรหัสข้อสอบ : 6-04-56-145
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading52
# ID foundรหัสข้อสอบ : 6-04-56-142
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Done, n(Correct) =  50
# n(Done) =  50
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# social DONE
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# is POSTTEST
# 3
# mathex  Taking POSTTEST
# ID foundรหัสข้อสอบ : J-40-15-102
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : J-40-15-81
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : J-40-15-109
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : J-40-15-104
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : J-40-15-84
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : J-40-15-110
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : J-40-15-91
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : J-40-15-96
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : J-40-15-95
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : J-40-15-99
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# SAVE_LECTURE not found
# SAVE_LECTURE not found
# is POSTTEST
# 3
# mathex  Taking POSTTEST
# ID foundรหัสข้อสอบ : J-40-16-201
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : J-40-16-207
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : J-40-16-212
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : J-40-16-205
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : J-40-16-216
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : J-40-16-211
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : J-40-16-203
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : J-40-16-193
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : J-40-16-200
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : J-40-16-191
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# is POSTTEST
# 3
# mathex  Taking POSTTEST
# ID foundรหัสข้อสอบ : J-40-17-174
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : J-40-17-163
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : J-40-17-175
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : J-40-17-164
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : J-40-17-160
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : J-40-17-188
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : J-40-17-151
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : J-40-17-152
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : J-40-17-170
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : J-40-17-184
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# is LECTURE
# 2
# is POSTTEST
# 3
# mathex  Taking POSTTEST
# ID foundรหัสข้อสอบ : J-40-18-125
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : J-40-18-122
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : J-40-18-139
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : J-40-18-123
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : J-40-18-117
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : J-40-18-134
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : J-40-18-148
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : J-40-18-133
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : J-40-18-118
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : J-40-18-130
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is FINALTEST
# 4
# ID foundรหัสข้อสอบ : J-40-15-102
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading4
# ID foundรหัสข้อสอบ : J-40-15-107
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading5
# ID foundรหัสข้อสอบ : J-40-15-83
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading6
# ID foundรหัสข้อสอบ : J-40-15-95
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading7
# ID foundรหัสข้อสอบ : J-40-15-94
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading8
# ID foundรหัสข้อสอบ : J-40-15-96
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading9
# ID foundรหัสข้อสอบ : J-40-15-82
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading10
# ID foundรหัสข้อสอบ : J-40-15-85
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading11
# ID foundรหัสข้อสอบ : J-40-15-110
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading12
# ID foundรหัสข้อสอบ : J-40-15-103
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading13
# ID foundรหัสข้อสอบ : J-40-15-88
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading14
# ID foundรหัสข้อสอบ : J-40-15-106
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading15
# ID foundรหัสข้อสอบ : J-40-15-97
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading16
# ID foundรหัสข้อสอบ : J-40-16-202
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading17
# ID foundรหัสข้อสอบ : J-40-16-196
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading18
# ID foundรหัสข้อสอบ : J-40-16-210
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading19
# ID foundรหัสข้อสอบ : J-40-16-212
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading20
# ID foundรหัสข้อสอบ : J-40-16-218
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading21
# ID foundรหัสข้อสอบ : J-40-16-220
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading22
# ID foundรหัสข้อสอบ : J-40-16-203
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading23
# ID foundรหัสข้อสอบ : J-40-16-211
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading24
# ID foundรหัสข้อสอบ : J-40-16-208
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading25
# ID foundรหัสข้อสอบ : J-40-16-198
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading26
# ID foundรหัสข้อสอบ : J-40-16-192
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading27
# ID foundรหัสข้อสอบ : J-40-16-191
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading28
# ID foundรหัสข้อสอบ : J-40-17-179
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading29
# ID foundรหัสข้อสอบ : J-40-17-160
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading30
# ID foundรหัสข้อสอบ : J-40-17-182
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading31
# ID foundรหัสข้อสอบ : J-40-17-175
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading32
# ID foundรหัสข้อสอบ : J-40-17-176
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading33
# ID foundรหัสข้อสอบ : J-40-17-173
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading34
# ID foundรหัสข้อสอบ : J-40-17-161
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading35
# ID foundรหัสข้อสอบ : J-40-17-151
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading36
# ID foundรหัสข้อสอบ : J-40-17-164
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading37
# ID foundรหัสข้อสอบ : J-40-17-169
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading38
# ID foundรหัสข้อสอบ : J-40-17-188
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading39
# ID foundรหัสข้อสอบ : J-40-17-168
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading40
# ID foundรหัสข้อสอบ : J-40-17-186
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading41
# ID foundรหัสข้อสอบ : J-40-18-119
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-d9b8067b1939> in <module>
#       6 data2.to_csv('/home/lloli/Documents/GitHub/Sorn/all.csv',index=False)
#       7
# ----> 8 auto_df_todo(df_todo)
#       9
#      10 shutdown()
#
# <ipython-input-41-77fa85a0c9c2> in auto_df_todo(df__todo)
#       8         pas  = df__todo.loc[i]['password']
#       9         sem = df__todo.loc[i]['semester']
# ---> 10         auto_usrsem2(name,usr,pas,'6/2','allterm21',data = df__todo)
#      11         df__todo.to_csv('usr/user_done_data.csv')
#      12
#
# <ipython-input-39-0d0410f2489b> in auto_usrsem2(name, usr, pas, semester, lst_subj_NAF, lst_subj_AF, except_NAF, except_AF, data)
#       8     click_ms6()
#       9     click_semester2()
# ---> 10     take_semester_df(lst_subj_NAF,lst_subj_AF,except_NAF,except_AF,name,semester,data = data)
#      11     time.sleep(1)
#      12     logout(name,usr)
#
# <ipython-input-37-46b25e6a5c96> in take_semester_df(lst_subj_NAF, lst_subj_AF, except_NAF, except_AF, name, semester, data)
#      66                 click_SUBJ(subj)
#      67
# ---> 68                 d = take_subject(False,lang,1,subj,name)
#      69                 if d == False:
#      70                     msg = '\nTaking {} in Semester 1'.format(subj)
#
# <ipython-input-31-e1a84d7bb514> in take_subject(at_final, lang, nwrong, subj, name)
#      75                 msg = subj +' Taking FINALTEST'
#      76                 notify(msg)
# ---> 77                 n,nn,inp = vsa.auto_take50(lang)
#      78                 time.sleep(2)
#      79                 vsl.send()
#
# ~/Documents/GitHub/Sorn/vs_auto.py in auto_take50(lang)
#     233                 sys.stdout.flush()
#     234                 time.sleep(0.25)
# --> 235                 if not auto.locateCenterOnScreen(id) == None:
#     236                     break
#     237         i = i+1
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in wrapper(*args, **kwargs)
#     173     def wrapper(*args, **kwargs):
#     174         try:
# --> 175             return wrappedFunction(*args, **kwargs)
#     176         except pyscreeze.ImageNotFoundException:
#     177             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in locateCenterOnScreen(*args, **kwargs)
#     205     @raisePyAutoGUIImageNotFoundException
#     206     def locateCenterOnScreen(*args, **kwargs):
# --> 207         return pyscreeze.locateCenterOnScreen(*args, **kwargs)
#     208
#     209     locateCenterOnScreen.__doc__ = pyscreeze.locateCenterOnScreen.__doc__
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyscreeze/__init__.py in locateCenterOnScreen(image, **kwargs)
#     398     TODO
#     399     """
# --> 400     coords = locateOnScreen(image, **kwargs)
#     401     if coords is None:
#     402         return None
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyscreeze/__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     358         try:
#     359             screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 360             retVal = locate(image, screenshotIm, **kwargs)
#     361             try:
#     362                 screenshotIm.fp.close()
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyscreeze/__init__.py in locate(needleImage, haystackImage, **kwargs)
#     338     # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     339     kwargs['limit'] = 1
# --> 340     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     341     if len(points) > 0:
#     342         return points[0]
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyscreeze/__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     217
#     218     # get all matches at once, credit: https://stackoverflow.com/questions/7670112/finding-a-subimage-inside-a-numpy-image/9253805#9253805
# --> 219     result = cv2.matchTemplate(haystackImage, needleImage, cv2.TM_CCOEFF_NORMED)
#     220     match_indices = numpy.arange(result.size)[(result > confidence).flatten()]
#     221     matches = numpy.unravel_index(match_indices[:limit], result.shape)
#
# KeyboardInterrupt:
