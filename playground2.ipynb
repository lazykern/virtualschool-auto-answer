# %%
import pyautogui as pag
import os
import time
import pandas as pd
import VSchool_lib as vsl
import vs_auto as vsa
import requests
import clipboard as cb
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import random
import numpy as np
SORN = '/home/lloli/Documents/GitHub/Sorn'
ter = os.path.join(SORN,'assets/$.png')
user_data_path = '/home/lloli/Documents/GitHub/Sorn/usr/user_data.csv'

# %%
token = '4HciAjHnI7lPRTz809eH4COiSVai7A4iPEG86P54lj7'
url = 'https://notify-api.line.me/api/notify'
headers = {
            'content-type':
            'application/x-www-form-urlencoded',
            'Authorization':'Bearer '+token
           }

# %%
def notify(msg):
    r = requests.post(url, headers=headers , data = {'message':msg})

# %%
def join_path(file_path):
    return os.path.join(SORN,file_path)

# %%
PATH = '/home/lloli/Documents/GitHub/Sorn'
YELLOW = os.path.join(PATH,'assets/yellow.png')
YELLOW_DARK = os.path.join(PATH,'assets/yellow_dark.png')
PRETEST = os.path.join(PATH,'assets/PRETEST.png')
LECTURE1 = os.path.join(PATH,'assets/LECTURE1.png')
LECTURE2 = os.path.join(PATH,'assets/LECTURE2.png')
LECTURE3 = os.path.join(PATH,'assets/LECTURE3.png')
LECTURE4 = os.path.join(PATH,'assets/lecture4.png')
SAVE_LECTURE = os.path.join(PATH,'assets/SAVE_LECTURE.png')
SAVE_LECTURE2 = os.path.join(PATH,'assets/SAVE_LECTURE2.png')
POSTTEST = os.path.join(PATH,'assets/POSTTEST.png')
LAST = os.path.join(PATH,'assets/LAST.png')
LAST2 = os.path.join(PATH,'assets/RE.png')
FINALTEST = os.path.join(PATH,'assets/FINAL.png')
REVIEW = os.path.join(PATH,'assets/again.png')
STAR = os.path.join(PATH,'assets/STAR.png')
PT_5 = os.path.join(PATH,'assets/pt_5.png')
PT_6 = os.path.join(PATH,'assets/pt_6.png')
PT_7 = os.path.join(PATH,'assets/pt_7.png')
PT_8 = os.path.join(PATH,'assets/pt_8.png')
PT_9 = os.path.join(PATH,'assets/pt_9.png')
PT_10 = os.path.join(PATH,'assets/pt_10.png')
PT_50 = os.path.join(PATH,'assets/pt_50.png')
ENG = os.path.join(PATH,'assets/fore.png')
OK = os.path.join(PATH,'assets/ok.png')
NOTDONE = os.path.join(PATH,'assets/notdone.png')

# %%
CHANGESUBJ = join_path('assets/CHANGESUBJ.png')
SUBJ_PHYSICS60 = join_path('assets/subjects/PHYSICS60.png')
SUBJ_MATH60 = join_path('assets/subjects/MATH60.png')
SUBJ_BIOLOGY60 = join_path('assets/subjects/BIOLOGY60.png')
SUBJ_CHEM60 = join_path('assets/subjects/CHEM60.png')
SUBJ_SOCIAL = join_path('assets/subjects/SOCIALSCIENCE.png')
SUBJ_TH = join_path('assets/subjects/THAI.png')
SUBJ_ENG = join_path('assets/subjects/ENG.png')
SUBJ_HE = join_path('assets/subjects/HE.png')
SUBJ_PE = join_path('assets/subjects/PE.png')
SUBJ_ART = join_path('assets/subjects/ART.png')
SUBJ_MATHEX = join_path('assets/subjects/MATHEX.png')
SUBJ_ASTRONOMY = join_path('assets/subjects/ASTRONOMY.png')
SUBJ_BIO = join_path('assets/subjects/bio.png')
SUBJ_MATH = join_path('assets/subjects/math.png')
SUBJ_CHEM = join_path('assets/subjects/chem.png')
USERNAME = join_path('assets/kpt.png')
PASSWORD = join_path('assets/pass.png')
LOGIN = join_path('assets/login.png')
LOGIN_AGREE = join_path('assets/login_agree.png')
KOY = join_path('assets/koy.png')
MS6 = join_path('assets/ms6.png')
SEMESTER1 = join_path('assets/semester1.png')
SEMESTER2 = join_path('assets/semester2.png')
LOGOUT = join_path('assets/logout.png')
HOME = join_path('assets/HOME.png')

# %%
def write_usr_pas(usr,pas):
    lc = pag.locateCenterOnScreen(USERNAME)
    if lc == None:
        pag.tripleClick(pag.Point(428,498))
        pag.hotkey('ctrl','c')
        err = 0
        while not 'kpt' in cb.paste():
            pag.tripleClick(pag.Point(428,498))
            pag.click(pag.Point(428,498))
            pag.hotkey('ctrl','c')
            err= err+1
            if err == 10:break
        pag.write(usr)
    else:
        pag.click(lc)
        pag.write(usr)


    lc = pag.locateCenterOnScreen(PASSWORD)
    if lc == None:
        pag.click(pag.Point(428,538))
        pag.hotkey('ctrl','a')
        pag.write(pas)
    else:
        pag.click(lc)
        pag.write(pas)

    msg = '\nUSERNAME = {} \nPASSWORD = {}'.format(usr,pas)
    notify(msg)
    print(msg)

# %%
def login():
    lc = pag.locateCenterOnScreen(LOGIN)
    if lc == None:
        pag.click(pag.Point(428,625))
    else:
        pag.click(lc)
    time.sleep(1)
    lc = pag.locateCenterOnScreen(LOGIN_AGREE)
    err = 0
    while lc == None:
        err = err + 1
        lc = pag.locateCenterOnScreen(LOGIN_AGREE)
        time.sleep(0.4)
        if err == 5:
            break

    pag.click(lc)
    print('LOGGED IN')
    time.sleep(2)

# %%
def click_koy():
    lc = pag.locateCenterOnScreen(KOY)
    if lc == None:
        pag.click(pag.Point(x=1101, y=896))
    else:
        pag.click(lc)  
    msg = 'Clicked Koy'
    notify(msg)
    print(msg)

# %%
def click_ms6():
    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(MS6)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(MS6)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=1308, y=828))
    else:
        pag.click(lc)  
    msg = 'Clicked MS6'
    notify(msg)
    print(msg)

# %%
def click_semester2():
    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(SEMESTER2)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(SEMESTER2)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=800, y=896))
    else:
        pag.click(lc)  

    msg = 'Clicked Semester 2'
    notify(msg)
    print(msg)

# %%
def click_semester1():
    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(SEMESTER1)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(SEMESTER1)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=1101, y=896))
    else:
        pag.click(lc)  

    msg = 'Clicked Semester 2'
    notify(msg)
    print(msg)

# %%
def logout(name = None,usr = None):

    pag.moveTo(100,100)
    lc = pag.locateCenterOnScreen(LOGOUT)
    err = 0
    while lc == None:
        err = err+1
        lc = pag.locateCenterOnScreen(LOGOUT)
        if err == 5: break
    if lc == None:
        pag.click(pag.Point(x=1418, y=331))
    else:
        pag.click(lc)  

    msg = 'Logged Out {}'.format(usr)
    notify(msg)
    print(msg)

# %%
def shutdown():
    pag.keyDown('ctrl')
    pag.keyDown('alt')
    time.sleep(0.5)
    pag.press('t')
    pag.keyUp('ctrl')
    pag.keyUp('alt')
    time.sleep(2)
    pag.write('sudo shutdown -h now')
    time.sleep(0.5)
    msg = 'Shutting down'
    print(msg)
    notify(msg)
    pag.press('enter')
    time.sleep(2)
    pag.write('@@#$pooh13164')
    pag.press('enter')

# %%
g_login = GoogleAuth()
g_login.LocalWebserverAuth()
drive = GoogleDrive(g_login)

folderName = 'vschool_fukk'

folders = drive.ListFile(
    {'q': "title='" + folderName + "' and mimeType='application/vnd.google-apps.folder' and trashed=false"}).GetList()
for folder in folders:
    if folder['title'] == folderName:
        folderID = folder['id']
file1 = drive.CreateFile({'title':'VSCHOOL_FULL_ANS.csv','parents': [{'id': folderID}]})
file2 = drive.CreateFile({'title':'USR.csv','parents': [{'id': folderID}]})
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=860236391617-bcbmishunp3rasacu3je1982ic0v04qh.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
def notify_IFTTT(a):
    report = {}
    report['value1'] = a
    requests.post("https://maker.ifttt.com/trigger/Final_Ace/with/key/cLvSycLN_IBxyYbpoy49QQ", data=report)

# %%
def click_STAR():
    lc = pag.locateCenterOnScreen(STAR)
    pag.click(lc)

# %%
def find_YELLOW():
    lc = pag.locateCenterOnScreen(YELLOW)
    if lc == None:
        lc = pag.locateCenterOnScreen(YELLOW_DARK)
    return lc

# %%
def find_LAST():
    lc = pag.locateCenterOnScreen(LAST)
    if lc == None:
        lc = pag.locateCenterOnScreen(LAST2)
    while lc == None:
        pag.press('pagedown')
        time.sleep(1)
        lc = pag.locateCenterOnScreen(LAST)
        if lc == None:
            lc = pag.locateCenterOnScreen(LAST2)
        
    return lc

# %%
def click_YELLOW(AT_FINAL):
    if AT_FINAL == False:
        lc = find_YELLOW()
        while lc == None: 

            lc = find_YELLOW()

            if lc == None:
                pag.press('pagedown')
                time.sleep(1)
                lc = find_YELLOW()

            lc = find_YELLOW()

            if lc == None:
                click_STAR()
                time.sleep(1)
                lc = find_YELLOW()
                if lc == None:
                    click_STAR()
                    time.sleep(1)
                    lc = find_YELLOW()
                    if lc == None: 
                        click_STAR()    
                        time.sleep(1)
                        lc = find_YELLOW()
                        if lc == None: 
                            click_STAR()    
                            time.sleep(1)
                            lc = find_YELLOW()
                            if lc == None: 
                                click_STAR()    
                                time.sleep(1)
                                lc = find_YELLOW()
                                if lc == None: 
                                    click_STAR()    
                                    time.sleep(1)
                                    lc = find_YELLOW()
            if lc == None:
                for i in range(5):
                    pag.press('pageup')

            lc = find_YELLOW()

    if AT_FINAL == True:
        lc = find_LAST()
    pag.click(lc)

# %%
def is_PRETEST():
    lc = pag.locateCenterOnScreen(PRETEST)
    if lc == None: return False
    else: return True

# %%
def is_POSTTEST():
    lc = pag.locateCenterOnScreen(POSTTEST)
    if lc == None: return False
    else: return True

# %%
def is_LECTURE():
    lc = pag.locateCenterOnScreen(LECTURE1)
    z = 0
    if lc == None:
        lc = pag.locateCenterOnScreen(LECTURE2)
        z = 1
        if lc == None:
            lc = pag.locateCenterOnScreen(LECTURE3)
            z = 0
            if lc == None:
                lc = pag.locateCenterOnScreen(LECTURE4)
                z = 0
    if lc == None: return False
    else: return True

# %%
def skip_LECTURE():
    lc = pag.locateCenterOnScreen(LECTURE1)
    z = 0
    if lc == None:
        lc = pag.locateCenterOnScreen(LECTURE2)
        z = 1
        if lc == None:
            lc = pag.locateCenterOnScreen(LECTURE3)
            z = 0
            if lc == None:
                lc = pag.locateCenterOnScreen(LECTURE4)
                z = 0
        
    
    err = 1
    
    while lc == None:
        lc = pag.locateCenterOnScreen(LECTURE1)
        z = 0
        if lc == None:
            lc = pag.locateCenterOnScreen(LECTURE2)
            z = 1
            if lc == None:
                lc = pag.locateCenterOnScreen(LECTURE3)
                z = 0
                if lc == None:
                    lc = pag.locateCenterOnScreen(LECTURE4)
                    z = 0
                    err = err +1
                    if err == 5: break

    if lc == None:
        lc = pag.Point(x=1441, y=382)

    if z == 0:
        pag.click(lc)
        lc = pag.locateCenterOnScreen(SAVE_LECTURE)
        if lc == None:
             lc = pag.locateCenterOnScreen(SAVE_LECTURE2)
        while lc == None:
            lc = pag.locateCenterOnScreen(SAVE_LECTURE)
            if lc == None:
                lc = pag.locateCenterOnScreen(SAVE_LECTURE2)
                print('SAVE_LECTURE not found')
        pag.click(lc)
    
    elif z == 1:
        pag.click(lc)

# %%
def is_FINALTEST():
    lc = pag.locateCenterOnScreen(FINALTEST)
    if lc == None: return False
    else: return True

# %%
def is_REVIEW():
    lc = pag.locateCenterOnScreen(REVIEW)
    if lc == None: return False
    else: return True

# %%
def get_PT():
    i = 0
    lc = None
    while lc == None:
        lc = pag.locateCenterOnScreen(PT_5)
        if not lc == None: 
            print(5,'pts')
            return 5
        lc = pag.locateCenterOnScreen(PT_6)
        if not lc == None: 
            print(6,'pts')
            return 6
        lc = pag.locateCenterOnScreen(PT_7)
        if not lc == None: 
            print(7,'pts')
            return 7
        lc = pag.locateCenterOnScreen(PT_8)
        if not lc == None: 
            print(8,'pts')
            return 8
        lc = pag.locateCenterOnScreen(PT_9)
        if not lc == None: 
            print(9,'pts')
            return 9
        lc = pag.locateCenterOnScreen(PT_10)
        if not lc == None: 
            print(10,'pts')
            return 10
        lc = pag.locateCenterOnScreen(PT_50)
        if not lc == None: 
            print(50,'pts')
            return 50
        i = i +1
        if i == 3:
            return 0

# %%
def get_TYPE():
    p = 0
    while p == 0:
        if is_PRETEST():
            print('is PRETEST')
            p=1
        elif is_LECTURE():
            print('is LECTURE')
            p=2
        elif is_POSTTEST():
            print('is POSTTEST')
            p=3
        elif is_FINALTEST():
            print('is FINALTEST')
            p=4
        elif is_REVIEW():
            print('is REVIEW')
            p=4
    print(p)
    return p

# %%
def take_subject(at_final = False,lang= 'th',nwrong = 1,subj=None,name = None):
    if subj == None:
        subj = ''
    AT_FINAL = at_final
    
    FINALTEST_ACED = False
    time.sleep(1)

    ok = pag.locateCenterOnScreen(OK)
    notdone = pag.locateCenterOnScreen(NOTDONE)
    if (not ok == None) or (not notdone == None):
        pag.press('enter')
        lc = pag.locateCenterOnScreen(NOTDONE)
        while lc == None:
            lc = pag.locateCenterOnScreen(NOTDONE)

        pag.click(lc)
        return False

    while FINALTEST_ACED == False:
        file1.Upload()
        pt = 0
        time.sleep(1)


        click_YELLOW(AT_FINAL)
        p = get_TYPE()

        if p == 1:
            vsl.send()
            time.sleep(1)
            vsl.confirm()
            vsl.x()
            pt = 0
        if p == 2:
            skip_LECTURE()
            pt = 0
        if p == 3:
            while pt < 5:
                print(subj,' Taking POSTTEST')
                msg = subj + ' Taking POSTTEST'
                notify(msg)
                n,nn = vsa.auto_take10(lang,nwrong)
                time.sleep(2)
                vsl.send()
                vsl.confirm()
                pt = get_PT()
                msg = subj+'\nn(Correct) = ' +str(n) +'\nn(Done) = ' + str(nn)
                notify(msg)
                if not n == 10:
                    
                    pag.moveTo(x=1463, y=489)
                    vsl.agree_PT()
                    vsl.gather()
                    file1.SetContentFile('/home/lloli/Documents/GitHub/Sorn/all.csv')
                    file1.Upload()
                    break
                else:
                    vsl.decline()
                    msg = subj + ' POSTTEST Passed'
                    notify(msg)
                    break
            msg = subj+ ' POSTTEST Done'
            notify(msg)
            pt = 0
                    

        if p == 4:
            AT_FINAL = True
            msg = subj + ' AT_FINAL'
            notify(msg)
            notify_IFTTT(msg)
            n = 0
            while not n == 50:
                msg = subj +' Taking FINALTEST'
                notify(msg)
                n,nn,inp = vsa.auto_take50(lang)
                time.sleep(2)
                vsl.send()
                vsl.confirm()
                msg = subj +'\nn(Correct) = ' +str(n) +'\nn(Done) = ' + str(nn)
                notify(msg)

                if n == 50:
                    pag.moveTo(x=1463, y=489)
                    time.sleep(2)
                    vsl.decline()
                    FINALTEST_ACED = True
                    msg = 'FINALTEST Aced'
                    notify(msg)
                    notify_IFTTT(msg)
                    break

                
                pag.moveTo(x=1463, y=489)
                time.sleep(2)
                vsl.agree_PT()
                vsl.gather()
                file1.SetContentFile('/home/lloli/Documents/GitHub/Sorn/all.csv')
                file1.Upload()
                click_YELLOW(True)
                


            msg = 'FINALTEST Done'
            notify(msg)

# %%
# for sec in range(3):
#     time.sleep(1)

# if  pag.locateCenterOnScreen(ENG) == None:
#     lang = 'th'
# else: lang = 'en'
# msg = 'LANG = ' + lang
# print(msg)
# notify(msg)
# take_subject(False,lang = 'en')

# %%
def click_CHANGESUBJ():
    lc = pag.locateCenterOnScreen(CHANGESUBJ)
    while lc == None:
        lc = pag.locateCenterOnScreen(CHANGESUBJ)
        if lc == None: print('CHANGESUBJ not found')
    pag.click(lc)
    pag.moveTo(1788,589)

# %%
def click_SUBJ(subj):
    pag.moveTo(100,100)
    switcher = {
        'phy60':SUBJ_PHYSICS60,
        'math60':SUBJ_MATH60,
        'bio60':SUBJ_BIOLOGY60,
        'chem60':SUBJ_CHEM60,
        'social':SUBJ_SOCIAL,
        'th':SUBJ_TH,
        'eng':SUBJ_ENG,
        'he':SUBJ_HE,
        'pe':SUBJ_PE,
        'art':SUBJ_ART,
        'mathex':SUBJ_MATHEX,
        'astro':SUBJ_ASTRONOMY,
        'math' :SUBJ_MATH,
        'bio' :SUBJ_BIO,
        'chem' :SUBJ_CHEM
    }

    lc = pag.locateCenterOnScreen(switcher[subj])
    while lc == None:
        pag.press('pagedown')
        time.sleep(1)
        lc = pag.locateCenterOnScreen(switcher[subj])
        if lc == None:
            pag.press('pagedown')
            time.sleep(1)
            lc = pag.locateCenterOnScreen(switcher[subj])
        if lc == None:
            pag.press('pageup')
            time.sleep(1)
            lc = pag.locateCenterOnScreen(switcher[subj])
        if lc == None:
            pag.press('pageup')
            time.sleep(1)
            lc = pag.locateCenterOnScreen(switcher[subj])
    pag.click(lc)

# %%
def click_HOME():
    lc = pag.locateCenterOnScreen(HOME)
    err = 0 
    while lc == None:
        lc = pag.locateCenterOnScreen(HOME)
        err = err+1
        if err == 7:
            break
    if lc == None:
        pag.click(pag.Point(x=449, y=340))
    else: pag.click(lc)

# %%
def listToString(s):  
    
    str1 = ""  
     
    for ele in s:  
        str1 += ele 
        str1 += ' ' 
     
    return str1

# %%
def take_semester_df(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2',data = None):


    
    if lst_subj_NAF == 'all':
        lst_subj_NAF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_AF == 'all':
        lst_subj_AF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_NAF == 'allterm2':
        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']


    ind = df[(df['name']== name) & (df['semester']== semester)].index[0]
    al_sbj_done = list(data[data['name']== name ]['subject_done'].values)[0]

    if type(al_sbj_done) == type(1.0):
        al_sbj_done = []
        except_NAF = []
    else:
        except_NAF = al_sbj_done.replace("'",'').replace("[",'').replace("]",'').replace(" ",'').split(',')
    
    if not except_NAF == []:
        for rm_subj in except_NAF:
            lst_subj_NAF.remove(rm_subj)

        msg = listToString(except_NAF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)
    else: 
        except_NAF = []

    notify('except_NAF = ' + str(except_NAF))


    
    if not except_AF == None:
        for rm_subj in except_AF:
            lst_subj_AF.remove(rm_subj)

        msg = listToString(except_AF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)

    if not lst_subj_NAF == None:
        random.shuffle(lst_subj_NAF)
        subj_todo = len(lst_subj_NAF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_NAF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                d = take_subject(False,lang,1,subj,name)
                if d == False:
                    msg = '\nTaking {} in Semester 1'.format(subj)
                    click_semester1()
                    click_SUBJ(subj)
                    take_subject(False,lang,1,subj)
                    click_HOME()
                    click_koy()
                    click_ms6()
                    click_semester2()
                    take_subject(False,lang,1,subj)


                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                except_NAF.append(subj)
                df.at[ind,'subject_done'] = except_NAF
                df.to_csv(user_data_path)
                file2.SetContentFile(user_data_path)
                file2.Upload()
                subj_done = subj_done + 1
                time.sleep(2)


                click_CHANGESUBJ()


    if not lst_subj_AF == None:
        random.shuffle(lst_subj_AF)
        subj_todo = len(lst_subj_AF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_AF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                take_subject(True,lang,5,subj,name)

                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                subj_done = subj_done + 1

                time.sleep(2)

                click_CHANGESUBJ()

# %%
def take_semester(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2'):


    
    if lst_subj_NAF == 'all':
        lst_subj_NAF = ['math60','phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_AF == 'all':
        lst_subj_AF = ['math60','phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_NAF == 'allterm2':
        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']


    if not except_NAF == []:
        for rm_subj in except_NAF:
            lst_subj_NAF.remove(rm_subj)

        msg = listToString(except_NAF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)
    else: 
        except_NAF = []

    notify('except_NAF = ' + str(except_NAF))


    
    if not except_AF == None:
        for rm_subj in except_AF:
            lst_subj_AF.remove(rm_subj)

        msg = listToString(except_AF) + ' REMOVED'
        time.sleep(2)
        notify(msg)
        print(msg)

    if not lst_subj_NAF == None:
        random.shuffle(lst_subj_NAF)
        subj_todo = len(lst_subj_NAF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_NAF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                d = take_subject(False,lang,1,subj,name)
                if d == False:
                    msg = '\nTaking {} in Semester 1'.format(subj)
                    click_semester1()
                    click_SUBJ(subj)
                    take_subject(False,lang,1,subj)
                    click_HOME()
                    click_koy()
                    click_ms6()
                    click_semester2()
                    take_subject(False,lang,1,subj)


                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                except_NAF.append(subj)
                subj_done = subj_done + 1
                time.sleep(2)


                click_CHANGESUBJ()


    if not lst_subj_AF == None:
        random.shuffle(lst_subj_AF)
        subj_todo = len(lst_subj_AF)
        subj_done = 0
        while not subj_done == subj_todo:
            for subj in lst_subj_AF:
                if subj == 'eng': lang = 'en'
                else: lang = 'th'
                pag.moveTo(100,100)
                time.sleep(2)
                click_SUBJ(subj)

                take_subject(True,lang,5,subj,name)

                msg = subj + ' DONE'
                notify(msg)
                print(msg)
                subj_done = subj_done + 1

                time.sleep(2)

                click_CHANGESUBJ()

# %%
def auto_usrsem2(name,usr,pas,semester,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None,data = None):
    msg = '\nName : {}'.format(name)
    notify(msg)
    print(msg)
    write_usr_pas(usr,pas)
    login()
    click_koy()
    click_ms6()
    click_semester2()
    take_semester_df(lst_subj_NAF,lst_subj_AF,except_NAF,except_AF,name,semester,data = data)
    time.sleep(1)
    logout(name,usr)
    time.sleep(5)

# %%
def auto_usrsem1(name,usr,pas,semester,df,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None,data = None):
    msg = '\nName : {}'.format(name)
    notify(msg)
    print(msg)
    write_usr_pas(usr,pas)
    login()
    click_koy()
    click_ms6()
    click_semester1()
    take_semester_df(lst_subj_NAF,lst_subj_AF,except_NAF,except_AF,name,semester,data)
    time.sleep(1)
    logout(name,usr)
    time.sleep(5)

# %%
def auto_df_todo(df__todo):

    print(df__todo)

    for i in range(df__todo.shape[0]):
        name = df__todo.loc[i]['name']
        usr = df__todo.loc[i]['username']
        pas  = df__todo.loc[i]['password']
        sem = df__todo.loc[i]['semester']
        auto_usrsem2(name,usr,pas,'6/2','allterm2',data = df__todo)
        df__todo.loc[i] = df__todo.loc[i].replace('standby','awaiting')
        df__todo.to_csv('usr/user_done_data.csv')

        ind = df[df['name']== name].index[0]
        df.at[ind,'status'] = 'awaiting'
        df.to_csv(user_data_path,index=False)
        file2.SetContentFile(user_data_path)
        file2.Upload()

# %%
def auto_df_todo2(df__todo):

    for i in range(df__todo.shape[0]):
        name = df__todo.loc[i]['name']
        usr = df__todo.loc[i]['username']
        pas  = df__todo.loc[i]['password']
        sem = df__todo.loc[i]['semester']
        auto_usrsem1(name,usr,pas,'6/1','all',data = df__todo)
        df__todo.loc[i] = df__todo.loc[i].replace('standby','awaiting')
        df__todo.to_csv('usr/user_done_data.csv')

        ind = df[df['name']== name].index[0]
        df.at[ind,'status'] = 'awaiting'
        df.to_csv(user_data_path,index=False)
        file2.SetContentFile(user_data_path)
        file2.Upload()

# %%
'''
SUBJ_PHYSICS60 = join_path('assets/subjects/PHYSICS60.png')
SUBJ_MATH60 = join_path('assets/subjects/MATH60.png')
SUBJ_BIOLOGY60 = join_path('assets/subjects/BIOLOGY60.png')
SUBJ_CHEM60 = join_path('assets/subjects/CHEM60.png')
SUBJ_SOCIAL = join_path('assets/subjects/SOCIALSCIENCE.png')
SUBJ_TH = join_path('assets/subjects/THAI.png')
SUBJ_ENG = join_path('assets/subjects/ENG.png')
SUBJ_HE = join_path('assets/subjects/HE.png')
SUBJ_PE = join_path('assets/subjects/PE.png')
SUBJ_MATHEX = join_path('assets/subjects/MATHEX.png')
SUBJ_ASTRONOMY = join_path('assets/subjects/ASTRONOMY.png')
------------------------------------------------------------
        'phy60':SUBJ_PHYSICS60,
        'math60':SUBJ_MATH60,
        'bio60':SUBJ_BIghgh f  'astro':SUBJ_ASTRONOMY
j
    if lst_subhubj_AF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']


    if lst_subj_NAF == 'allterm2':
        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']

--------------------------------------------------------------------------------
take_semester(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2')

auto_sem2(name,usr,pas,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None)
'''
# Out:
# "\nSUBJ_PHYSICS60 = join_path('assets/subjects/PHYSICS60.png')\nSUBJ_MATH60 = join_path('assets/subjects/MATH60.png')\nSUBJ_BIOLOGY60 = join_path('assets/subjects/BIOLOGY60.png')\nSUBJ_CHEM60 = join_path('assets/subjects/CHEM60.png')\nSUBJ_SOCIAL = join_path('assets/subjects/SOCIALSCIENCE.png')\nSUBJ_TH = join_path('assets/subjects/THAI.png')\nSUBJ_ENG = join_path('assets/subjects/ENG.png')\nSUBJ_HE = join_path('assets/subjects/HE.png')\nSUBJ_PE = join_path('assets/subjects/PE.png')\nSUBJ_MATHEX = join_path('assets/subjects/MATHEX.png')\nSUBJ_ASTRONOMY = join_path('assets/subjects/ASTRONOMY.png')\n------------------------------------------------------------\n        'phy60':SUBJ_PHYSICS60,\n        'math60':SUBJ_MATH60,\n        'bio60':SUBJ_BIghgh f  'astro':SUBJ_ASTRONOMY\nj\n    if lst_subhubj_AF = ['phy60','chem60','bio60','social','th','eng','he','pe','art','mathex','astro']\n\n\n    if lst_subj_NAF == 'allterm2':\n        lst_subj_NAF = ['chem60','social','th','eng','he','pe','mathex','astro']\n\n--------------------------------------------------------------------------------\ntake_semester(lst_subj_NAF=None,lst_subj_AF=None,except_NAF=[],except_AF=[],name = None,semester = '6/2')\n\nauto_sem2(name,usr,pas,lst_subj_NAF=None,lst_subj_AF=None,except_NAF=None,except_AF=None)\n"

# %%
data = pd.read_csv('/home/lloli/Documents/GitHub/Sorn/all.csv')
data = data.drop(data[data['id'] == data['ans']].index)
data.to_csv('/home/lloli/Documents/GitHub/Sorn/all.csv')

take_semester(lst_subj_NAF=['bio'],lst_subj_AF=['phy60','math','astro', 'pe', 'th', 'he', 'mathex', 'eng', 'chem60', 'social'],except_NAF=[],except_AF=['math','astro', 'pe', 'th', 'he', 'mathex', 'eng', 'chem60', 'social'],name = None,)
# Out:
# math astro pe th he mathex eng chem60 social  REMOVED
# is REVIEW
# 4
# ID foundรหัสข้อสอบ : 4-08-01-845
#
# 'รหัสข้อสอบ : 4-08-01-845' is not in the Database
# Loading4
# Done, n(Correct) =  0
# n(Done) =  1
# Clicked SEND
# Loading
# Loading
# Loading
# Clicked CONFIRM
# Clicked AGREE
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# 4-08-01-845
# ก
# clicked NEXT/HUB
# Quiz Number: 1
#
# ID not Found
# ID not Found
# ID not Found
# 4-08-01-285
# ก
# NEXT not Found
# clicked NEXT/HUB
# Quiz Number: 2
#
# ID not Found
# ID not Found
# 4-08-02-320
# ง
# NEXT not Found
# clicked NEXT/HUB
# Quiz Number: 3
#
# ID not Found
# 4-08-02-361
# ข
# clicked NEXT/HUB
# Quiz Number: 4
#
# 4-08-03-379
# ก
# clicked NEXT/HUB
# Quiz Number: 5
#
# 4-08-03-83
# ก
# clicked NEXT/HUB
# Quiz Number: 6
#
# 4-08-04-899
# ค
# clicked NEXT/HUB
# Quiz Number: 7
#
# 4-08-04-891
# ข
# clicked NEXT/HUB
# Quiz Number: 8
#
# ID not Found
# 4-08-05-655
# ง
# clicked NEXT/HUB
# Quiz Number: 9
#
# 4-08-05-925
# ก
# clicked NEXT/HUB
# Quiz Number: 10
#
# 4-08-06-483
# ข
# clicked NEXT/HUB
# Quiz Number: 11
#
# 4-08-06-154
# ค
# clicked NEXT/HUB
# Quiz Number: 12
#
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# 4-08-07-968
# ก
# clicked NEXT/HUB
# Quiz Number: 13
#
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# 4-08-07-133
# ข
# clicked NEXT/HUB
# Quiz Number: 14
#
# ID not Found
# ID not Found
# 4-08-08-360
# ก
# clicked NEXT/HUB
# Quiz Number: 15
#
# ID not Found
# ID not Found
# ID not Found
# 4-08-08-988
# ค
# clicked NEXT/HUB
# Quiz Number: 16
#
# 4-08-09-145
# ค
# clicked NEXT/HUB
# Quiz Number: 17
#
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# 4-08-09-691
# ง
# clicked NEXT/HUB
# Quiz Number: 18
#
# 4-08-10-1022
# ง
# clicked NEXT/HUB
# Quiz Number: 19
#
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# 4-08-10-494
# ก
# clicked NEXT/HUB
# Quiz Number: 20
#
# 5-08-11-227
# ง
# clicked NEXT/HUB
# Quiz Number: 21
#
# 5-08-11-31
# ง
# clicked NEXT/HUB
# Quiz Number: 22
#
# 5-08-12-772
# ค
# clicked NEXT/HUB
# Quiz Number: 23
#
# ID not Found
# 5-08-12-28
# ค
# clicked NEXT/HUB
# Quiz Number: 24
#
# 5-08-13-249
# ง
# clicked NEXT/HUB
# Quiz Number: 25
#
# 5-08-13-790
# ค
# clicked NEXT/HUB
# Quiz Number: 26
#
# 5-08-14-136
# ข
# clicked NEXT/HUB
# Quiz Number: 27
#
# ID not Found
# 5-08-14-686
# ข
# clicked NEXT/HUB
# Quiz Number: 28
#
# ID not Found
# 5-08-15-883
# ก
# clicked NEXT/HUB
# Quiz Number: 29
#
# 5-08-15-314
# ค
# clicked NEXT/HUB
# Quiz Number: 30
#
# 5-08-16-557
# ก
# clicked NEXT/HUB
# Quiz Number: 31
#
# ID not Found
# 5-08-16-537
# ง
# clicked NEXT/HUB
# Quiz Number: 32
#
# ID not Found
# 5-08-17-840
# ง
# clicked NEXT/HUB
# Quiz Number: 33
#
# ID not Found
# 5-08-17-588
# ก
# clicked NEXT/HUB
# Quiz Number: 34
#
# 5-08-17-719
# ข
# clicked NEXT/HUB
# Quiz Number: 35
#
# ID not Found
# 5-08-18-667
# ค
# clicked NEXT/HUB
# Quiz Number: 36
#
# 5-08-18-430
# ข
# clicked NEXT/HUB
# Quiz Number: 37
#
# 5-08-18-671
# ข
# clicked NEXT/HUB
# Quiz Number: 38
#
# ID not Found
# 6-08-19-262
# ง
# clicked NEXT/HUB
# Quiz Number: 39
#
# 6-08-19-209
# ข
# clicked NEXT/HUB
# Quiz Number: 40
#
# 6-08-19-26
# ง
# clicked NEXT/HUB
# Quiz Number: 41
#
# 6-08-20-523
# ข
# clicked NEXT/HUB
# Quiz Number: 42
#
# 6-08-20-509
# จ
# clicked NEXT/HUB
# Quiz Number: 43
#
# ID not Found
# ID not Found
# 6-08-20-321
# ก
# clicked NEXT/HUB
# Quiz Number: 44
#
# 6-08-21-381
# ก
# clicked NEXT/HUB
# Quiz Number: 45
#
# ID not Found
# ID not Found
# ID not Found
# ID not Found
# 6-08-21-403
# ก
# clicked NEXT/HUB
# Quiz Number: 46
#
# 6-08-21-378
# ค
# clicked NEXT/HUB
# Quiz Number: 47
#
# 6-08-22-494
# ง
# NEXT not Found
# clicked NEXT/HUB
# Quiz Number: 48
#
# ID not Found
# ID not Found
# 6-08-22-52
# ก
# clicked NEXT/HUB
# Quiz Number: 49
#
# 6-08-22-593
# ค
# NEXT not Found
# NEXT not Found
# NEXT not Found
# clicked NEXT/HUB
# Quiz Number: 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-83a978f31415> in <module>
#       3 data.to_csv('/home/lloli/Documents/GitHub/Sorn/all.csv')
#       4
# ----> 5 take_semester(lst_subj_NAF=['bio'],lst_subj_AF=['phy60','math','astro', 'pe', 'th', 'he', 'mathex', 'eng', 'chem60', 'social'],except_NAF=[],except_AF=['math','astro', 'pe', 'th', 'he', 'mathex', 'eng', 'chem60', 'social'],name = None,)
#
# <ipython-input-36-a4612eb5c1fa> in take_semester(lst_subj_NAF, lst_subj_AF, except_NAF, except_AF, name, semester)
#      51                 click_SUBJ(subj)
#      52
# ---> 53                 d = take_subject(False,lang,1,subj,name)
#      54                 if d == False:
#      55                     msg = '\nTaking {} in Semester 1'.format(subj)
#
# <ipython-input-29-e1a84d7bb514> in take_subject(at_final, lang, nwrong, subj, name)
#      99                 file1.SetContentFile('/home/lloli/Documents/GitHub/Sorn/all.csv')
#     100                 file1.Upload()
# --> 101                 click_YELLOW(True)
#     102
#     103
#
# <ipython-input-20-26e6f6879c73> in click_YELLOW(AT_FINAL)
#      44
#      45     if AT_FINAL == True:
# ---> 46         lc = find_LAST()
#      47     pag.click(lc)
#
# <ipython-input-19-17728736e137> in find_LAST()
#       2     lc = pag.locateCenterOnScreen(LAST)
#       3     while lc == None:
# ----> 4         pag.press('pagedown')
#       5         time.sleep(1)
#       6         lc = pag.locateCenterOnScreen(LAST)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in wrapper(*args, **kwargs)
#     585         failSafeCheck()
#     586         returnVal = wrappedFunction(*args, **kwargs)
# --> 587         _handlePause(kwargs.get("_pause", True))
#     588         return returnVal
#     589
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in _handlePause(_pause)
#     629     if _pause:
#     630         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 631         time.sleep(PAUSE)
#     632
#     633
#
# KeyboardInterrupt:

# %%
vsl.confirm()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-480365f5cdef> in <module>
# ----> 1 vsl.confirm()
#
# ~/Documents/GitHub/Sorn/VSchool_lib.py in confirm()
#     166     lc = pag.locateCenterOnScreen(ยืน)
#     167     if lc == None:
# --> 168         lc = pag.locateCenterOnScreen(confirm2)
#     169
#     170     while lc == None:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in wrapper(*args, **kwargs)
#     173     def wrapper(*args, **kwargs):
#     174         try:
# --> 175             return wrappedFunction(*args, **kwargs)
#     176         except pyscreeze.ImageNotFoundException:
#     177             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in locateCenterOnScreen(*args, **kwargs)
#     205     @raisePyAutoGUIImageNotFoundException
#     206     def locateCenterOnScreen(*args, **kwargs):
# --> 207         return pyscreeze.locateCenterOnScreen(*args, **kwargs)
#     208
#     209     locateCenterOnScreen.__doc__ = pyscreeze.locateCenterOnScreen.__doc__
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyscreeze/__init__.py in locateCenterOnScreen(image, **kwargs)
#     398     TODO
#     399     """
# --> 400     coords = locateOnScreen(image, **kwargs)
#     401     if coords is None:
#     402         return None
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyscreeze/__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     357     while True:
#     358         try:
# --> 359             screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
#     360             retVal = locate(image, screenshotIm, **kwargs)
#     361             try:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyscreeze/__init__.py in _screenshot_linux(imageFilename, region)
#     473         tmpFilename = imageFilename
#     474     if scrotExists:
# --> 475         subprocess.call(['scrot', '-z', tmpFilename])
#     476         im = Image.open(tmpFilename)
#     477
#
# ~/anaconda3/envs/py36/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
# --> 289             return p.wait(timeout=timeout)
#     290         except:
#     291             p.kill()
#
# ~/anaconda3/envs/py36/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/envs/py36/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
# df = pd.read_csv('/home/lloli/Documents/GitHub/Sorn/usr/user_data.csv')
# df = df[(df.semester=='6/2') & (df.status == 'standby')].reset_index(drop=True)
# auto_df_todo(df)
# shutdown()
# Out:
#    name  username  password class semester      subject_done subject_todo  \
# 0  Golf  kpt24146  kpt24146   6/2      6/2  ['th', 'social']          All
# 1   Win  kpt16988  kpt16988   6/3      6/2            ['pe']          NaN
# 2  Bomb  kpt15971  kpt15971   6/2      6/2               NaN          All
#
#    price   paid   status
# 0  300.0  300.0  standby
# 1  300.0  300.0  standby
# 2  300.0  300.0  standby
#
# Name : Golf
#
# USERNAME = kpt24146
# PASSWORD = kpt24146
# LOGGED IN
# Clicked Koy
# Clicked MS6
# Clicked Semester 2
# th social  REMOVED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# pe  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-39-51-109
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-39-51-101
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-39-51-91
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-39-51-106
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-39-51-93
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-39-51-108
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-39-51-102
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-39-51-104
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-39-51-99
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-39-51-92
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# pe  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-39-52-111
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-39-52-116
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-39-52-119
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-39-52-112
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-39-52-113
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-39-52-117
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-39-52-114
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-39-52-120
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-39-52-118
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-39-52-115
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# pe  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-39-53-139
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-39-53-132
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-39-53-138
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-39-53-136
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-39-53-129
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-39-53-127
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-39-53-137
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-39-53-126
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-39-53-130
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-39-53-124
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is FINALTEST
# 4
# ID foundรหัสข้อสอบ : 6-39-51-92
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading4
# ID foundรหัสข้อสอบ : 6-39-51-107
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading5
# ID foundรหัสข้อสอบ : 6-39-51-100
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading6
# ID foundรหัสข้อสอบ : 6-39-51-103
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading7
# ID foundรหัสข้อสอบ : 6-39-51-101
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading8
# ID foundรหัสข้อสอบ : 6-39-51-97
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading9
# ID foundรหัสข้อสอบ : 6-39-51-108
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading10
# ID foundรหัสข้อสอบ : 6-39-51-95
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading11
# ID foundรหัสข้อสอบ : 6-39-51-93
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading12
# ID foundรหัสข้อสอบ : 6-39-51-91
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading13
# ID foundรหัสข้อสอบ : 6-39-51-104
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading14
# ID foundรหัสข้อสอบ : 6-39-51-109
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading15
# ID foundรหัสข้อสอบ : 6-39-51-105
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading16
# ID foundรหัสข้อสอบ : 6-39-51-99
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading17
# ID foundรหัสข้อสอบ : 6-39-51-106
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading18
# ID foundรหัสข้อสอบ : 6-39-51-102
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading19
# ID foundรหัสข้อสอบ : 6-39-51-96
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading20
# ID foundรหัสข้อสอบ : 6-39-51-94
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading21
# ID foundรหัสข้อสอบ : 6-39-51-110
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading22
# ID foundรหัสข้อสอบ : 6-39-51-98
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading23
# ID foundรหัสข้อสอบ : 6-39-51-98
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading24
# ID foundรหัสข้อสอบ : 6-39-52-111
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading25
# ID foundรหัสข้อสอบ : 6-39-52-116
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading26
# ID foundรหัสข้อสอบ : 6-39-52-119
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading27
# ID foundรหัสข้อสอบ : 6-39-52-120
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading28
# ID foundรหัสข้อสอบ : 6-39-52-118
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading29
# ID foundรหัสข้อสอบ : 6-39-52-114
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading30
# ID foundรหัสข้อสอบ : 6-39-52-112
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading31
# ID foundรหัสข้อสอบ : 6-39-52-115
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading32
# ID foundรหัสข้อสอบ : 6-39-52-117
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading33
# ID foundรหัสข้อสอบ : 6-39-53-135
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading34
# ID foundรหัสข้อสอบ : 6-39-53-131
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading35
# ID foundรหัสข้อสอบ : 6-39-53-133
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading36
# ID foundรหัสข้อสอบ : 6-39-53-123
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading37
# ID foundรหัสข้อสอบ : 6-39-53-127
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading38
# ID foundรหัสข้อสอบ : 6-39-53-126
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading39
# ID foundรหัสข้อสอบ : 6-39-53-136
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading40
# ID foundรหัสข้อสอบ : 6-39-53-140
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading41
# ID foundรหัสข้อสอบ : 6-39-53-134
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading42
# ID foundรหัสข้อสอบ : 6-39-53-128
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading43
# ID foundรหัสข้อสอบ : 6-39-53-137
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading44
# ID foundรหัสข้อสอบ : 6-39-53-129
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading45
# ID foundรหัสข้อสอบ : 6-39-53-125
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading46
# ID foundรหัสข้อสอบ : 6-39-53-121
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading47
# ID foundรหัสข้อสอบ : 6-39-53-138
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading48
# ID foundรหัสข้อสอบ : 6-39-53-139
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading49
# ID foundรหัสข้อสอบ : 6-39-53-122
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading50
# ID foundรหัสข้อสอบ : 6-39-53-124
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading51
# ID foundรหัสข้อสอบ : 6-39-53-132
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading52
# ID foundรหัสข้อสอบ : 6-39-53-130
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Done, n(Correct) =  50
# n(Done) =  50
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# pe DONE
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# eng  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-05-50-313
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-05-50-750
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-05-50-585
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-05-50-422
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-05-50-227
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-05-50-355
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-05-50-370
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-05-50-755
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-05-50-587
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-05-50-15
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# eng  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-05-51-250
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-05-51-23
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-05-51-272
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-05-51-27
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-05-51-720
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-05-51-28
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-05-51-729
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-05-51-301
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-05-51-723
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-05-51-30
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# eng  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-05-52-647
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-05-52-330
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-05-52-380
# 4
# Choice not found
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-05-52-627
# 1
# Choice not found
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-05-52-415
# 5
# Choice not found
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-05-52-58
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-05-52-456
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-05-52-529
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-05-52-635
# 1
# Choice not found
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-05-52-409
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# eng  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-05-53-485
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-05-53-499
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-05-53-63
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-05-53-77
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-05-53-546
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-05-53-454
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-05-53-534
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-05-53-467
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-05-53-523
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-05-53-693
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is PRETEST
# 1
# Clicked SEND
# Clicked CONFIRM
# Clicked X
# is LECTURE
# 2
# SAVE_LECTURE not found
# is LECTURE
# 2
# is POSTTEST
# 3
# eng  Taking POSTTEST
# ID foundรหัสข้อสอบ : 6-05-54-85
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  4
# ID foundรหัสข้อสอบ : 6-05-54-604
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  5
# ID foundรหัสข้อสอบ : 6-05-54-609
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading
#  6
# ID foundรหัสข้อสอบ : 6-05-54-83
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  7
# ID foundรหัสข้อสอบ : 6-05-54-660
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading
#  8
# ID foundรหัสข้อสอบ : 6-05-54-96
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading
#  9
# ID foundรหัสข้อสอบ : 6-05-54-87
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  10
# ID foundรหัสข้อสอบ : 6-05-54-673
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  11
# ID foundรหัสข้อสอบ : 6-05-54-431
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading
#  12
# ID foundรหัสข้อสอบ : 6-05-54-659
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Done, n(Correct) =  10
# n(Done) =  10
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# is FINALTEST
# 4
# ID foundรหัสข้อสอบ : 6-05-50-217
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading4
# ID foundรหัสข้อสอบ : 6-05-50-308
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading5
# ID foundรหัสข้อสอบ : 6-05-50-348
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading6
# ID foundรหัสข้อสอบ : 6-05-50-588
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading7
# ID foundรหัสข้อสอบ : 6-05-50-737
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading8
# ID foundรหัสข้อสอบ : 6-05-50-423
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading9
# ID foundรหัสข้อสอบ : 6-05-50-353
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading10
# ID foundรหัสข้อสอบ : 6-05-50-346
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading11
# ID foundรหัสข้อสอบ : 6-05-50-314
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading12
# ID foundรหัสข้อสอบ : 6-05-50-369
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading13
# ID foundรหัสข้อสอบ : 6-05-51-300
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading14
# ID foundรหัสข้อสอบ : 6-05-51-729
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading15
# ID foundรหัสข้อสอบ : 6-05-51-256
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading16
# ID foundรหัสข้อสอบ : 6-05-51-735
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading17
# ID foundรหัสข้อสอบ : 6-05-51-249
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading18
# ID foundรหัสข้อสอบ : 6-05-51-31
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading19
# ID foundรหัสข้อสอบ : 6-05-51-21
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading20
# ID foundรหัสข้อสอบ : 6-05-51-242
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading21
# ID foundรหัสข้อสอบ : 6-05-51-272
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading22
# ID foundรหัสข้อสอบ : 6-05-51-251
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading23
# ID foundรหัสข้อสอบ : 6-05-52-384
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading24
# ID foundรหัสข้อสอบ : 6-05-52-320
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading25
# ID foundรหัสข้อสอบ : 6-05-52-552
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading26
# ID foundรหัสข้อสอบ : 6-05-52-42
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading27
# ID foundรหัสข้อสอบ : 6-05-52-260
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading28
# ID foundรหัสข้อสอบ : 6-05-52-698
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading29
# ID foundรหัสข้อสอบ : 6-05-52-623
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading30
# ID foundรหัสข้อสอบ : 6-05-52-46
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading31
# ID foundรหัสข้อสอบ : 6-05-52-559
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading32
# ID foundรหัสข้อสอบ : 6-05-52-261
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading33
# ID foundรหัสข้อสอบ : 6-05-53-75
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading34
# ID foundรหัสข้อสอบ : 6-05-53-345
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading35
# ID foundรหัสข้อสอบ : 6-05-53-591
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading36
# ID foundรหัสข้อสอบ : 6-05-53-349
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading37
# ID foundรหัสข้อสอบ : 6-05-53-687
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading38
# ID foundรหัสข้อสอบ : 6-05-53-530
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading39
# ID foundรหัสข้อสอบ : 6-05-53-528
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading40
# ID foundรหัสข้อสอบ : 6-05-53-452
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading41
# ID foundรหัสข้อสอบ : 6-05-53-341
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading42
# ID foundรหัสข้อสอบ : 6-05-53-406
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading43
# ID foundรหัสข้อสอบ : 6-05-53-406
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading44
# ID foundรหัสข้อสอบ : 6-05-54-428
# 3
#
#
# Choice found
# ( 3 ) Choice clicked
#
#
# Loading45
# ID foundรหัสข้อสอบ : 6-05-54-618
# 5
#
#
# Choice found
# ( 5 ) Choice clicked
#
#
# Loading46
# ID foundรหัสข้อสอบ : 6-05-54-602
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading47
# ID foundรหัสข้อสอบ : 6-05-54-431
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading48
# ID foundรหัสข้อสอบ : 6-05-54-89
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading49
# ID foundรหัสข้อสอบ : 6-05-54-672
# 4
#
#
# Choice found
# ( 4 ) Choice clicked
#
#
# Loading50
# ID foundรหัสข้อสอบ : 6-05-54-668
# 2
#
#
# Choice found
# ( 2 ) Choice clicked
#
#
# Loading51
# ID foundรหัสข้อสอบ : 6-05-54-669
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Loading52
# ID foundรหัสข้อสอบ : 6-05-54-662
# 1
#
#
# Choice found
# ( 1 ) Choice clicked
#
#
# Done, n(Correct) =  50
# n(Done) =  50
# Clicked SEND
# Clicked CONFIRM
# Clicked UNWANTED
# eng DONE
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-69-44dc384fd169> in <module>
#       1 df = pd.read_csv('/home/lloli/Documents/GitHub/Sorn/usr/user_data.csv')
#       2 df = df[(df.semester=='6/2') & (df.status == 'standby')].reset_index(drop=True)
# ----> 3 auto_df_todo(df)
#       4 shutdown()
#
# <ipython-input-38-839b0b47f0fa> in auto_df_todo(df__todo)
#       8         pas  = df__todo.loc[i]['password']
#       9         sem = df__todo.loc[i]['semester']
# ---> 10         auto_usrsem2(name,usr,pas,'6/2','allterm2',data = df__todo)
#      11         df__todo.loc[i] = df__todo.loc[i].replace('standby','awaiting')
#      12         df__todo.to_csv('usr/user_done_data.csv')
#
# <ipython-input-36-0d0410f2489b> in auto_usrsem2(name, usr, pas, semester, lst_subj_NAF, lst_subj_AF, except_NAF, except_AF, data)
#       8     click_ms6()
#       9     click_semester2()
# ---> 10     take_semester_df(lst_subj_NAF,lst_subj_AF,except_NAF,except_AF,name,semester,data = data)
#      11     time.sleep(1)
#      12     logout(name,usr)
#
# <ipython-input-34-5021e55281de> in take_semester_df(lst_subj_NAF, lst_subj_AF, except_NAF, except_AF, name, semester, data)
#      60                 click_SUBJ(subj)
#      61
# ---> 62                 d = take_subject(False,lang,1,subj,name)
#      63                 if d == False:
#      64                     msg = '\nTaking {} in Semester 1'.format(subj)
#
# <ipython-input-28-e1a84d7bb514> in take_subject(at_final, lang, nwrong, subj, name)
#      24
#      25
# ---> 26         click_YELLOW(AT_FINAL)
#      27         p = get_TYPE()
#      28
#
# <ipython-input-20-26e6f6879c73> in click_YELLOW(AT_FINAL)
#      18                 lc = find_YELLOW()
#      19                 if lc == None:
# ---> 20                     click_STAR()
#      21                     time.sleep(1)
#      22                     lc = find_YELLOW()
#
# <ipython-input-17-48e5f8dcd2e1> in click_STAR()
#       1 def click_STAR():
#       2     lc = pag.locateCenterOnScreen(STAR)
# ----> 3     pag.click(lc)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in wrapper(*args, **kwargs)
#     583     @functools.wraps(wrappedFunction)
#     584     def wrapper(*args, **kwargs):
# --> 585         failSafeCheck()
#     586         returnVal = wrappedFunction(*args, **kwargs)
#     587         _handlePause(kwargs.get("_pause", True))
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pyautogui/__init__.py in failSafeCheck()
#    1709     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
#    1710         raise FailSafeException(
# -> 1711             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1712         )
#    1713
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
pag.locateCenterOnScreen(vsl.ยืนน)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-7ad327b99c87> in <module>
# ----> 1 pag.locateCenterOnScreen(vsl.ยืนน)
#
# AttributeError: module 'VSchool_lib' has no attribute 'ยืนน'
